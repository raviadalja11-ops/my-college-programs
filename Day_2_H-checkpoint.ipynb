# %%
# Electricity Billing System

user = int(input("Enter Electricity Unit: "))

bill = 0

if user <= 200:
    bill = user * 6
elif user <= 250:
    bill = (200 * 6) + ((user - 200) * 7)
else:
    bill = (200 * 6) + (50 * 7) + ((user - 250) * 8)

print("Total Bill = ₹", bill)
# Out:
# Enter Electricity Unit:  400
# Total Bill = ₹ 2750

# %%
# Converter 

while True:
    print("\n 1.Decimal to Binary")
    print("\n 2.Decimal to Octal")
    print("\n 3.Decimal to Hexa")
    print("\n 0.Exit")

    ch = int(input("Enter Any One Choice: "))

    if ch == 1: 
        no = int(input("Enter Decimal No: "))
        print("Binary No: ", bin(no))
    elif ch == 2:
        no = int(input("Enter Decimal No: "))
        print("Octal No: ",  oct(no))        
    elif ch == 3:
        no = int(input("Enter Decimal No: "))
        print("HexaDecimal No: ", hex(no))
    elif ch == 0:
        break
# Out:
#  1.Decimal to Binary
#
#  2.Decimal to Octal
#
#  3.Decimal to Hexa
#
#  0.Exit
# Enter Any One Choice:  1
# Enter Decimal No:  2
# Binary No:  0b10
#
#  1.Decimal to Binary
#
#  2.Decimal to Octal
#
#  3.Decimal to Hexa
#
#  0.Exit
# Enter Any One Choice:  2
# Enter Decimal No:  5
# Octal No:  0o5
#
#  1.Decimal to Binary
#
#  2.Decimal to Octal
#
#  3.Decimal to Hexa
#
#  0.Exit
# Enter Any One Choice:  3
# Enter Decimal No:  5
# HexaDecimal No:  0x5
#
#  1.Decimal to Binary
#
#  2.Decimal to Octal
#
#  3.Decimal to Hexa
#
#  0.Exit
# Enter Any One Choice:  0
